# %% [markdown]
# <a href="https://colab.research.google.com/github/poojaharihar03/Web-scrapes/blob/main/hindi_movies_scrape.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Website:https://en.wikipedia.org/wiki/List_of_Hindi_films_of_1980

# %%
from bs4 import BeautifulSoup
import requests

# %%
response = requests.get('https://en.wikipedia.org/wiki/List_of_Hindi_films_of_1980')

# %%
response.status_code
# Out:
# 200

# %%
print(response.text[:1000])
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-zebra-design-enabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-client-prefs-pinned-disabled vector-toc-available" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8">
# <title>List of Hindi films of 1980 - Wikipedia</title>
# ...

# %%
type(response.text)
# Out:
# str

# %%
html = response.text

# %%
data = BeautifulSoup(html,'html.parser')

# %%
data
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-zebra-design-enabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-client-prefs-pinned-disabled vector-toc-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of Hindi films of 1980 - Wikipedia</title>
# ...

# %%
print(data.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-zebra-design-enabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-client-prefs-pinned-disabled vector-toc-available" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    List of Hindi films of 1980 - Wikipedia
#   </title>
#   <script>
# ...

# %%
data.title
# Out:
# <title>List of Hindi films of 1980 - Wikipedia</title>

# %%
print(data.title.string)
# Out:
# List of Hindi films of 1980 - Wikipedia

# %%
import re
heading_before_table = data.find_all('h2')
heading_before_table
# Out:
# [<h2 class="vector-pinnable-header-label">Contents</h2>,
#  <h2><span class="mw-headline" id="Successful_stars_of_the_year">Successful stars of the year</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=List_of_Hindi_films_of_1980&amp;action=edit&amp;section=1" title="Edit section: Successful stars of the year"><span>edit</span></a><span class="mw-editsection-bracket">]</span></span></h2>,
#  <h2><span class="mw-headline" id="Top-grossing_films">Top-grossing films</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=List_of_Hindi_films_of_1980&amp;action=edit&amp;section=2" title="Edit section: Top-grossing films"><span>edit</span></a><span class="mw-editsection-bracket">]</span></span></h2>,
# ...

# %%
heading_before_table = data.find('h2')
heading_before_table
# Out:
# <h2 class="vector-pinnable-header-label">Contents</h2>

# %%
table_data = data.find_all('table', class_='wikitable')
len(table_data)
# Out:
# 1

# %%
table_data
# Out:
# [<table class="wikitable">
#  <tbody><tr>
#  <th>Title</th>
#  <th>Director</th>
#  <th>Cast</th>
#  <th>Genre</th>
#  <th>Sources
#  </th></tr>
#  <tr>
#  <td><i><a href="/wiki/Aakrosh_(1980_film)" title="Aakrosh (1980 film)">Aakrosh</a></i></td>
#  <td><a href="/wiki/Govind_Nihalani" title="Govind Nihalani">Govind Nihalani</a></td>
#  <td><a href="/wiki/Naseeruddin_Shah" title="Naseeruddin Shah">Naseeruddin Shah</a>, <a href="/wiki/Smita_Patil" title="Smita Patil">Smita Patil</a>, <a href="/wiki/Amrish_Puri" title="Amrish Puri">Amrish Puri</a></td>
#  <td>Drama, Mystery, Thriller</td>
#  <td>
#  </td></tr>
#  <tr>
#  <td><i><a href="/wiki/Aanchal_(1980_film)" title="Aanchal (1980 film)">Aanchal</a></i></td>
#  <td><a href="/wiki/Anil_Ganguly" title="Anil Ganguly">Anil Ganguly</a></td>
# ...

# %%
table_data = data.find('table',class_='wikitable')
rows = table_data.find_all('tr')

# %%
rows
# Out:
# [<tr>
#  <th>Title</th>
#  <th>Director</th>
#  <th>Cast</th>
#  <th>Genre</th>
#  <th>Sources
#  </th></tr>,
#  <tr>
#  <td><i><a href="/wiki/Aakrosh_(1980_film)" title="Aakrosh (1980 film)">Aakrosh</a></i></td>
#  <td><a href="/wiki/Govind_Nihalani" title="Govind Nihalani">Govind Nihalani</a></td>
#  <td><a href="/wiki/Naseeruddin_Shah" title="Naseeruddin Shah">Naseeruddin Shah</a>, <a href="/wiki/Smita_Patil" title="Smita Patil">Smita Patil</a>, <a href="/wiki/Amrish_Puri" title="Amrish Puri">Amrish Puri</a></td>
#  <td>Drama, Mystery, Thriller</td>
#  <td>
#  </td></tr>,
#  <tr>
#  <td><i><a href="/wiki/Aanchal_(1980_film)" title="Aanchal (1980 film)">Aanchal</a></i></td>
#  <td><a href="/wiki/Anil_Ganguly" title="Anil Ganguly">Anil Ganguly</a></td>
#  <td><a href="/wiki/Rajesh_Khanna" title="Rajesh Khanna">Rajesh Khanna</a>, <a class="mw-redirect" href="/wiki/Raakhee" title="Raakhee">Raakhee</a>, <a href="/wiki/Rekha" title="Rekha">Rekha</a></td>
# ...

# %%
movies = []
for row in rows:
    curr_movie = []
    for cell in row.find_all("td"):
        if cell.string != "\n" and cell.string != None:
            curr_movie.append(cell.string)
        else:
            curr_movie.append("NA")
    movies.append(curr_movie)
    #print(curr_movie)
print(movies)
# Out:
# [[], ['Aakrosh', 'Govind Nihalani', 'NA', 'Drama, Mystery, Thriller', 'NA'], ['Aanchal', 'Anil Ganguly', 'NA', 'Action, Family, Drama, Comedy', 'NA'], ['Aap Ke Deewane', 'Surendra Mohan', 'NA', 'Romance', 'NA'], ['Aap To Aise Na The', 'Ambrish Sangal', 'NA', 'Romance, Drama, Family', 'NA'], ['Aasha', 'J. Om Prakash', 'NA', 'Drama, Family, Musical, Romance', 'NA'], ['Abdullah', 'Sanjay Khan', 'NA', 'Action, Drama, Family', 'NA'], ['Abhimanyu', 'Mahesh Bhatt', 'NA', 'NA', 'NA'], ['Agent 009', 'NA', 'NA', 'Action', 'NA'], ['Agreement', 'Anil Ganguly', 'NA', 'Musical, Comedy, Drama, Family', 'NA'], ['Akhri Insaaf', 'Kalidas', 'NA', 'Action', 'NA'], ['Albert Pinto Ko Gussa Kyoon Aata Hai', 'Saeed Akhtar Mirza', 'NA', 'Comedy, Drama, Romance', 'NA'], ['Alibaba Aur 40 Chor', 'NA', 'NA', 'Action, Adventure, Family, Romance', 'NA'], ['Ambe Maa Jagdambe Maa', 'Sukhdev Ahluwalia', 'NA', 'History, Comedy, Drama, Family', 'NA'], ['Angaar', 'Ashok Roy', 'NA', 'Suspense', 'NA'], ['Apne Paraye', 'Ba
# ...

# %%
import pandas as pd

df = pd.DataFrame()

for row in movies:
    if len(row) != 0:
        df = df.append({'Movie Name' : row[0],
                       'Director' : row[1],
                       'Cast' : row[2],
                       'Genre': row[3]},ignore_index= True)
# Out:
# <ipython-input-19-076e1c25b33c>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Movie Name' : row[0],
# <ipython-input-19-076e1c25b33c>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Movie Name' : row[0],
# <ipython-input-19-076e1c25b33c>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Movie Name' : row[0],
# <ipython-input-19-076e1c25b33c>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Movie Name' : row[0],
# ...

# %%
print(df)
# Out:
#              Movie Name             Director Cast  \
# 0               Aakrosh      Govind Nihalani   NA
# 1               Aanchal         Anil Ganguly   NA
# 2        Aap Ke Deewane       Surendra Mohan   NA
# 3    Aap To Aise Na The       Ambrish Sangal   NA
# 4                 Aasha        J. Om Prakash   NA
# ..                  ...                  ...  ...
# 107          Unees-Bees        Swaroop Kumar   NA
# 108       Yari Dushmani      Sikandar Khanna   NA
# 109    Yeh Kaisa Insaf?  Narayana Rao Dasari   NA
# 110   Zakhmon Ke Nishan        Diljeet Bassi   NA
# 111               Zalim           B. Subhash   NA
#
#                                Genre
# 0           Drama, Mystery, Thriller
# 1      Action, Family, Drama, Comedy
# 2                            Romance
# 3             Romance, Drama, Family
# 4    Drama, Family, Musical, Romance
# ..                               ...
# 107                               NA
# 108                               NA
# ...

# %%
df.head()
# Out:
#            Movie Name         Director Cast                            Genre
# 0             Aakrosh  Govind Nihalani   NA         Drama, Mystery, Thriller
# 1             Aanchal     Anil Ganguly   NA    Action, Family, Drama, Comedy
# 2      Aap Ke Deewane   Surendra Mohan   NA                          Romance
# 3  Aap To Aise Na The   Ambrish Sangal   NA           Romance, Drama, Family
# 4               Aasha    J. Om Prakash   NA  Drama, Family, Musical, Romance

# %%
df.tail()
# Out:
#             Movie Name             Director Cast   Genre
# 107         Unees-Bees        Swaroop Kumar   NA      NA
# 108      Yari Dushmani      Sikandar Khanna   NA      NA
# 109   Yeh Kaisa Insaf?  Narayana Rao Dasari   NA   Drama
# 110  Zakhmon Ke Nishan        Diljeet Bassi   NA  Action
# 111              Zalim           B. Subhash   NA      NA

# %%
df.describe()
# Out:
#        Movie Name Director Cast Genre
# count         112      112  112   112
# unique        112       95    7    44
# top       Aakrosh       NA   NA    NA
# freq            1        6  106    30
